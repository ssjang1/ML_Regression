# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X.csv'

phh_X = pd.read_csv(path)
phh_X
# Out:
#       수고(m)  수관폭1(min)  수관폭2(max)  수관폭평균
# 0     275.0      287.0      292.0  289.5
# 1     293.0      284.0      336.0  310.0
# 2     300.0      392.0      450.0  421.0
# 3     289.0      368.0      379.0  373.5
# 4     306.0      353.0      358.0  355.5
# ...     ...        ...        ...    ...
# 2202  230.0      353.0      367.0  360.0
# 2203  266.0      337.0      400.0  368.5
# 2204  237.0      353.0      362.0  357.5
# 2205  281.0      337.0      403.0  370.0
# 2206  228.0      389.0      398.0  393.5
#
# [2207 rows x 4 columns]

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X_date.csv'

phh_X_date = pd.read_csv(path)
phh_X_date
# Out:
#       2022-09-01 새순  2022-09-02 새순  2022-09-03 새순  2022-09-04 새순  \
# 0               2.8            2.8            2.7            2.7
# 1               3.3            3.3            3.3            3.2
# 2               3.0            2.9            2.9            2.9
# 3               3.1            3.0            3.0            3.0
# 4               3.7            3.6            3.6            3.6
# ...             ...            ...            ...            ...
# 2202            4.7            4.6            4.5            4.5
# 2203            3.1            3.0            3.0            3.0
# 2204            3.0            3.0            2.9            2.9
# 2205            3.9            3.9            3.8            3.8
# 2206            5.3            5.2            5.2            5.1
#
#       2022-09-05 새순  2022-09-06 새순  2022-09-07 새순  2022-09-08 새순  \
# 0               2.7            2.7            2.6            2.6
# ...

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X_scaled_date.csv'

phh_X_scaled_date = pd.read_csv(path)
phh_X_scaled_date
# Out:
#       2022-09-01 새순  2022-09-02 새순  2022-09-03 새순  2022-09-04 새순  \
# 0         -1.259189      -1.226165      -1.327204      -1.292671
# 1         -0.613180      -0.571607      -0.531966      -0.621661
# 2         -1.000786      -1.095253      -1.062125      -1.024267
# 3         -0.871584      -0.964342      -0.929585      -0.890065
# 4         -0.096373      -0.178873      -0.134347      -0.084852
# ...             ...            ...            ...            ...
# 2195       1.195646       1.130242       1.058510       1.122966
# 2196      -0.871584      -0.964342      -0.929585      -0.890065
# 2197      -1.000786      -0.964342      -1.062125      -1.024267
# 2198       0.162031       0.213862       0.130732       0.183552
# 2199       1.970857       1.915711       1.986288       1.928179
#
#       2022-09-05 새순  2022-09-06 새순  2022-09-07 새순  2022-09-08 새순  \
# 0         -1.263844      -1.225557      -1.333939      -1.299658
# ...

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X_month.csv'

phh_X_month = pd.read_csv(path)
phh_X_month
# Out:
#        9_새순mean    9_새순std  9_새순diff  9_새순min    9_새순max  10_새순mean  \
# 0     39.679723  37.572907      -0.7      2.1  78.336504  37.848992
# 1     40.570783  38.047215      -0.9      2.4  80.116691  38.214894
# 2     40.052357  37.798887      -0.8      2.2  79.118529  38.182065
# 3     39.597695  37.268093      -0.9      2.2  77.936262  37.647606
# 4     38.997656  36.158826      -1.1      2.6  76.233231  36.951384
# ...         ...        ...       ...      ...        ...        ...
# 2202  38.297475  34.673907      -1.5      3.2  74.024614  36.078733
# 2203  41.494033  39.175137      -0.8      2.3  81.920876  39.478707
# 2204  38.336298  36.047621      -0.8      2.2  75.486518  36.462033
# 2205  38.048754  34.999511      -1.1      2.8  74.110017  36.028045
# 2206  41.707891  37.580599      -1.7      3.6  80.830756  39.306223
#
#        10_새순std  10_새순diff  10_새순min   10_새순max  ...  10_엽록소mean  10_엽록소std  \
# ...

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X_scaled_month.csv'

phh_X_scaled_month = pd.read_csv(path)
phh_X_scaled_month
# Out:
#       9_새순mean   9_새순std  9_새순diff   9_새순min   9_새순max  10_새순mean  10_새순std  \
# 0     0.168475  0.568784  1.274715 -1.236115  0.362060   0.295950  0.521623
# 1     0.605676  0.800088  0.581507 -0.625002  0.805248   0.476023  0.601566
# 2     0.351309  0.678987  0.928111 -1.032410  0.556750   0.459867  0.652172
# 3     0.128227  0.420137  0.581507 -1.032410  0.262418   0.196842  0.342319
# 4    -0.166183 -0.120814 -0.111701 -0.217593 -0.161562  -0.145792 -0.135245
# ...        ...       ...       ...       ...       ...        ...       ...
# 2195 -0.509729 -0.844957 -1.498117  1.004633 -0.711410  -0.575253 -0.751996
# 2196  1.058670  1.350136  0.928111 -0.828706  1.254410   1.097988  1.249094
# 2197 -0.490680 -0.175045  0.928111 -1.032410 -0.347461  -0.386618 -0.202180
# 2198 -0.631764 -0.686171 -0.111701  0.189815 -0.690149  -0.600199 -0.615234
# 2199  1.163600  0.572535 -2.191325  1.819450  0.983019   1.013103  0.706623
#
# ...

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X_total.csv'

phh_X_total = pd.read_csv(path)
phh_X_total
# Out:
#         새순mean     새순std  새순diff  새순min  새순max    엽록소mean    엽록소std   엽록소diff  \
# 0     1.693258  0.638143    -2.2    0.6    2.8  74.155836  2.427798 -8.293252
# 1     1.861798  0.894491    -3.3    0.0    3.3  74.962123  2.813831 -9.689090
# 2     1.762921  0.712611    -2.5    0.5    3.0  74.727999  2.476758 -8.718951
# 3     1.857303  0.692802    -2.4    0.7    3.1  73.546210  2.641605 -8.802293
# 4     2.125843  0.898171    -3.1    0.6    3.7  71.841067  2.642378 -8.823138
# ...        ...       ...     ...    ...    ...        ...       ...       ...
# 2202  2.507865  1.248565    -4.7    0.0    4.7  69.822742  2.481985 -8.464066
# 2203  1.841573  0.712519    -2.5    0.6    3.1  77.262155  2.681104 -8.976479
# 2204  1.770787  0.723345    -2.5    0.5    3.0  71.165328  2.613637 -9.007058
# 2205  2.184270  1.021129    -3.9    0.0    3.9  70.019605  2.376784 -8.297933
# 2206  2.807865  1.441923    -5.3    0.0    5.3  76.090699  2.490503 -8.960244
#
#          엽록소min     엽록소max
# ...

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X_scaled_total.csv'

phh_X_scaled_total = pd.read_csv(path)
phh_X_scaled_total
# Out:
#         새순mean     새순std    새순diff     새순min     새순max   엽록소mean    엽록소std  \
# 0    -1.348076 -1.228196  1.187680  0.808606 -1.259189  0.415442 -0.932766
# 1    -0.852161 -0.245731  0.118096 -1.156704 -0.613180  0.615065  1.279782
# 2    -1.143098 -0.942796  0.895975  0.481054 -1.000786  0.557099 -0.652148
# 3    -0.865386 -1.018714  0.993210  1.136158 -0.871584  0.264509  0.292666
# 4    -0.075229 -0.231629  0.312566  0.808606 -0.096373 -0.157654  0.297098
# ...        ...       ...       ...       ...       ...       ...       ...
# 2195  1.048844  1.111271 -1.243192 -1.156704  1.195646 -0.657356 -0.622193
# 2196 -0.911671 -0.943146  0.895975  0.808606 -0.871584  1.184512  0.519057
# 2197 -1.119955 -0.901657  0.895975  0.481054 -1.000786 -0.324955  0.132369
# 2198  0.096688  0.239613 -0.465313 -1.156704  0.162031 -0.608616 -1.225151
# 2199  1.931572  1.852323 -1.826601 -1.156704  1.970857  0.894480 -0.573373
#
#        엽록소diff    엽록소min    엽록소max
# ...

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/y.csv'

phh_y = pd.read_csv(path)
phh_y
# Out:
#       착과량(int)
# 0          692
# 1          534
# 2          634
# 3          639
# 4          496
# ...        ...
# 2202       119
# 2203       611
# 2204       650
# 2205       363
# 2206        17
#
# [2207 rows x 1 columns]

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/y_scaled.csv'

phh_y_scaled = pd.read_csv(path)
phh_y_scaled

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X_scaled.csv'

phh_X_scaled = pd.read_csv(path)
phh_X_scaled
# Out:
#          수고(m)  수관폭1(min)  수관폭2(max)     수관폭평균
# 0     0.869490  -0.426210  -0.971593 -0.733604
# 1     1.370746  -0.471461  -0.332135 -0.417362
# 2     1.565679   1.157576   1.324643  1.294972
# 3     1.259356   0.795568   0.292790  0.562216
# 4     1.732765   0.569313  -0.012406  0.284541
# ...        ...        ...        ...       ...
# 2195 -0.383651   0.569313   0.118392  0.353959
# 2196  0.618862   0.327974   0.597986  0.485084
# 2197 -0.188718   0.569313   0.045727  0.315393
# 2198  1.036575   0.327974   0.641585  0.508224
# 2199 -0.439346   1.112325   0.568920  0.870745
#
# [2200 rows x 4 columns]
