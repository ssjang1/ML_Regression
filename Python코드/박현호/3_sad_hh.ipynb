# %% [markdown]
# 정규화 : X / 수고 / 수관폭평균 / 9월 1일 새순 / 엽록소 / 10월 1일 새순 / 엽록소

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X_date.csv'

phh_X_date = pd.read_csv(path)
phh_X_date
# Out:
#       2022-09-01 새순  2022-09-02 새순  2022-09-03 새순  2022-09-04 새순  \
# 0               2.8            2.8            2.7            2.7
# 1               3.3            3.3            3.3            3.2
# 2               3.0            2.9            2.9            2.9
# 3               3.1            3.0            3.0            3.0
# 4               3.7            3.6            3.6            3.6
# ...             ...            ...            ...            ...
# 2202            4.7            4.6            4.5            4.5
# 2203            3.1            3.0            3.0            3.0
# 2204            3.0            3.0            2.9            2.9
# 2205            3.9            3.9            3.8            3.8
# 2206            5.3            5.2            5.2            5.1
#
#       2022-09-05 새순  2022-09-06 새순  2022-09-07 새순  2022-09-08 새순  \
# 0               2.7            2.7            2.6            2.6
# ...

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/y.csv'

phh_y = pd.read_csv(path)
phh_y
# Out:
#       착과량(int)
# 0          692
# 1          534
# 2          634
# 3          639
# 4          496
# ...        ...
# 2202       119
# 2203       611
# 2204       650
# 2205       363
# 2206        17
#
# [2207 rows x 1 columns]

# %%
path = '/content/drive/MyDrive/ P - value/proj_3/데이터 파일/전처리데이터 (전후)/X.csv'

phh_X = pd.read_csv(path)
phh_X
# Out:
#       수고(m)  수관폭1(min)  수관폭2(max)  수관폭평균
# 0     275.0      287.0      292.0  289.5
# 1     293.0      284.0      336.0  310.0
# 2     300.0      392.0      450.0  421.0
# 3     289.0      368.0      379.0  373.5
# 4     306.0      353.0      358.0  355.5
# ...     ...        ...        ...    ...
# 2202  230.0      353.0      367.0  360.0
# 2203  266.0      337.0      400.0  368.5
# 2204  237.0      353.0      362.0  357.5
# 2205  281.0      337.0      403.0  370.0
# 2206  228.0      389.0      398.0  393.5
#
# [2207 rows x 4 columns]

# %%
phh = phh_y.loc[:, '착과량(int)'].copy()

# %%
phh = pd.concat([phh, phh_X[['수고(m)', '수관폭평균']]], axis=1)
phh = pd.concat([phh, phh_X_date[['2022-09-01 새순', '2022-10-01 새순', '2022-09-01 엽록소', '2022-10-01 엽록소']]], axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# X, y 나눠주기
X = phh.drop('착과량(int)', axis=1)  # 변수 열들을 X로 설정
y = phh['착과량(int)']  # 타겟 열을 y로 설정

# Train-Test 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=3)

# Random Forest Classifier 모델 생성 및 학습
rf = RandomForestClassifier(random_state=3)
rf.fit(X_train, y_train)

# 테스트 데이터에 대한 예측
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# 정확도를 계산해보자
accuracy = accuracy_score(y_test, y_pred)

print("정확도 : ", accuracy)
# Out:
# 정확도 :  0.010558069381598794

# %%
import numpy as np

# 예측값과 실제값의 차이 계산
errors = np.abs(y_pred - y_test)

# 오차 범위 통계량 계산
mean_error = np.mean(errors)
max_error = np.max(errors)
min_error = np.min(errors)
median_error = np.median(errors)
std_error = np.std(errors)

print("Mean Error:", mean_error)
print("Max Error:", max_error)
print("Min Error:", min_error)
print("Median Error:", median_error)
print("Standard Deviation of Error:", std_error)
# Out:
# Mean Error: 41.295625942684765
# Max Error: 185
# Min Error: 0
# Median Error: 32.0
# Standard Deviation of Error: 36.042334277956705

# %% [markdown]
# # 전처리를 안한 데이터가 정확도는 좀 더 높게나왔다 하지만 망했다.
